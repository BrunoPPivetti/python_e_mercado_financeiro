# %% [markdown]
# Listas não aceitam operações matemáticas, por isso, transforma-se em array para operações vetorizadas

# %%
x = [10, -2, 5]

# %%
x[1:3] - x[0:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 x[1:3] - x[0:2]
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
import numpy as np
vetor = np.array(x)
vetor
# Out:
# array([10, -2,  5])

# %%
resp = vetor[1:3] - vetor[0:2]
resp
# Out:
# [-12   7]
