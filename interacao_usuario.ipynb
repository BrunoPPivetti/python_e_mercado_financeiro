# %%
import math

# %%
x = float(input('Escolha um valor para X:'))
y = float(input('Escolha um valor para Y:'))

z = math.sqrt(x**2+y**2) - math.log(x) + math.exp(y)    

print(z)
# Out:
# 22.997941018091712
