# %%
import math

# %%
#numero de euler elevado a 1
math.exp(1)
# Out:
# 2.718281828459045

# %%
#log de 10 na base numero de euler
math.log(10)
# Out:
# 2.302585092994046

# %%
#log de 3 na base 2
math.log2(3)
# Out:
# 1.584962500721156

# %%
#potenciação. Nesse caso, 2 elevado a 3
math.pow(2, 3)
# Out:
# 8.0

# %%
#raiz quadrada de 16
math.sqrt(16)
# Out:
# 4.0

# %%
#seno de 3 radianos
math.sin(3)
# Out:
# 0.1411200080598672

# %%
#cosseno de 3 radianos
math.cos(3)
# Out:
# -0.9899924966004454

# %%
#tangente de 3 radianos
math.tan(3)
# Out:
# -0.1425465430742778

# %%
#convertendo ângulo de x em radianos para graus
math.degrees(3.14)
# Out:
# 179.9087476710785

# %%
#convertendo o ângulo de x em graus para radianos
math.radians(180)
# Out:
# 3.141592653589793
