# %%
x=[3,2,1]
f=open('dad.txt','w') #parâmetro w para escrita
f.write('%d %d %d\n' % (x[0],x[1],x[2])) #%d para inteiros, %s para strings, %a.bf para float
f.close()
# Out:
# 6

# %%
f.close()

# %%
f = open('dad.txt', 'r') #parametro r para leitura
y = f.read()
print(y)
# Out:
# 3 2 1

# %%
f.close()
